# %%
# %load_ext autoreload
import sys
import gc
import numpy as np 
from processing import get_MIST_dens
import matplotlib.pyplot as plt
from dataclasses import dataclass
import pickle


filename = r"C:\Users\ecsadmin\Downloads\f_c_18GHz_0.pkl"
with open(filename, "rb") as f:
    dat0 = pickle.load(f)

filename = r"C:\Users\ecsadmin\Downloads\f_c_18GHz_1.pkl"
with open(filename, "rb") as f:
    dat1 = pickle.load(f)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(dat0.keys())
# Out:
# dict_keys(['n_r_branch=q0_c0', 'n_q_branch=q0_c0', 'n_r_branch=q0_c1', 'n_q_branch=q0_c1', 'n_r_branch=q0_c2', 'n_q_branch=q0_c2', 'n_r_branch=q0_c3', 'n_q_branch=q0_c3', 'n_r_branch=q0_c4', 'n_q_branch=q0_c4', 'n_r_branch=q0_c5', 'n_q_branch=q0_c5'])

# %%
key_list0 = ['n_q_branch=q0_c0', 'n_q_branch=q0_c1', 'n_q_branch=q0_c2', 'n_q_branch=q0_c3']
name_list0 = [r'$⟨n_c⟩ = 0$', r'$⟨n_c⟩ = 1$', r'$⟨n_c⟩ = 2$', r'$⟨n_c⟩ = 3$']
key_list1 = ['n_q_branch=q1_c0', 'n_q_branch=q1_c1', 'n_q_branch=q1_c2', 'n_q_branch=q1_c3']

# %%
step =.02
flux_arr = np.arange(-.2, .6, step)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()
n_r_list = np.arange(0, 75, 1)
extent = [-.2, .6, n_r_list[0], n_r_list[-1]]

for ax, key, name in zip(axes, key_list0, name_list0):
    #ax.imshow(dat0[key].T, extent=extent, cmap='magma')
    ax.set_title(name)
    ax.set_xlabel('Flux (Φ/Φ₀)')
    ax.set_ylabel(r'$⟨n_r⟩$')
    fixed = Z_fixed = np.flipud(dat0[key].T)

    im = ax.imshow(fixed, extent=extent, cmap='magma', vmin=0, vmax=2)
    ax.set_aspect("auto")

    plt.colorbar(im, ax = ax)

title = r'$\Psi_{init} = |0⟩$'
fig.suptitle(title, fontsize=16)
plt.tight_layout()
plt.savefig(r'Ground State')

# %%
step =.02
flux_arr = np.arange(-.2, .6, step)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()
n_r_list = np.arange(0, 75, 1)
extent = [-.2, .6, n_r_list[0], n_r_list[-1]]

for ax, key, name in zip(axes, key_list1, name_list0):
    #ax.imshow(dat0[key].T, extent=extent, cmap='magma')
    ax.set_title(name)
    ax.set_xlabel('Flux (Φ/Φ₀)')
    ax.set_ylabel(r'$⟨n_r⟩$')
    fixed = Z_fixed = np.flipud(dat1[key].T)

    im = ax.imshow(fixed, extent=extent, cmap='magma', vmin=1, vmax=3)
    ax.set_aspect("auto")

    plt.colorbar(im, ax = ax)

title = r'$\Psi_{init} = |1⟩$'
fig.suptitle(title, fontsize=16)
plt.tight_layout()
plt.savefig(r'Excited State')

# %%
def get_MIST_dens(data, freq_range, n_r):
    key_list = [key for key in data.keys() if 'n_q' in key]
    for key in key_list:
        if '=q0' in key:
            ref_val = 0
        if '=q1' in key:
            ref_val = 1
        num_peaks, peaks_per, n_crit = peak_detection_2(data, key, ref_val, freq_range)
        
        tot_key  = key + '_tot'
        dens_key = key + '_dens'
        crit_key = key + '_n_crit'
        data[tot_key] = (num_peaks, None, ['n_r'])
        data[dens_key] = (peaks_per, None, ['n_r'])
        data[crit_key] = (n_crit, None, ['flux'])
        data[r'$\langle n_r \rangle$'] = (n_r, None, None) 
        
    return data

def peak_detection_2(data, key, ref_val, flux_range, threshold=.1, cluster_window=5):
      MIST_dat = np.flipud(data[key])  # shape (n_flux, n_r) - don't transpose
      ref_val = MIST_dat[:, 0]
      delta_nq = MIST_dat - ref_val[:, np.newaxis]
      
      n_flux, n_r_len = MIST_dat.shape
      peaks_vs_nr = np.zeros(n_r_len)
      n_crit = np.zeros(n_flux)
    
      for flux_idx in range(n_flux):
          row = delta_nq[flux_idx, :]
          jump_indices = np.where(row > threshold)[0]
          if len(jump_indices) == 0:
              continue
    
          # Cluster and assign each transition to a single n_r
          gaps = np.diff(jump_indices)
          split_points = np.where(gaps > cluster_window)[0] + 1
          clusters = np.split(jump_indices, split_points)
    
          for cluster in clusters:
              center = cluster[len(cluster) // 2]
              peaks_vs_nr[center] += 1
          diff = clusters[0][-1] - clusters[0][0]
          n_crit[flux_idx] = (clusters[0][-1] - clusters[0][0])
    
        
      # peaks_vs_nr[i] = number of flux points with a transition at n_r = i
      density_vs_nr = peaks_vs_nr / flux_range  # transitions per GHz at each n_r
      return np.cumsum(peaks_vs_nr), density_vs_nr, n_crit

# %%
filename = r"C:\Users\ecsadmin\Downloads\1 1.pkl"
with open(filename, "rb") as f:
    dat0 = pickle.load(f)

data_p = get_MIST_dens(dat0, 6, n_r_list)

# %%
key_list2 = []
for key in data_p.keys():
    if '_crit' in key:
        key_list2.append(key)

# %%
step =.002
flux_arr = np.arange(-.2, .6, )

# %%
for key in key_list2:
    plt.plot(80-np.flip(data_p[key][0]), label=key)
plt.ylabel('n_crit')
plt.xlabel('flux index')
plt.show()

# %%
step =.02
flux_arr = np.arange(-.2, .6, step)
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()
n_r_list = np.arange(0, 75, 1)
extent = [flux_arr[0], flux_arr[-1], n_r_list[0], n_r_list[-1]]

for ax, key, name in zip(axes, key_list1, name_list0):
    #ax.imshow(dat0[key].T, extent=extent, cmap='magma')
    ax.set_title(name)
    ax.set_xlabel('Flux (Φ/Φ₀)')
    ax.set_ylabel(r'$⟨n_r⟩$')
    fixed = Z_fixed = np.flipud(dat1[key].T)

    im = ax.imshow(fixed, extent=extent, cmap='magma', vmin=1, vmax=3)
    ax.set_aspect("auto")

    plt.colorbar(im, ax = ax)

title = r'$\Psi_{init} = |0⟩$'
fig.suptitle(title, fontsize=16)
plt.tight_layout()
plt.savefig(r'Ground State')

# %%
def get_weights(num, omega, temp):
    omega_list = omega * np.arange(1, num+1, 1)
    temp_GHz = temp * 20.83
    propto = np.exp(-omega_list / temp_GHz)
    return propto / np.sum(propto)

# %%
weights = get_weights(6, 1.5, .04)

# %%
small0 = [key for key in dat0.keys() if ('n_q') in key]
small1 = [key for key in dat1.keys() if ('n_q') in key]

# %%
therm0 = sum(weight * dat0[key] for weight, key in zip(weights, small0))  
therm1 = sum(weight * dat1[key] for weight, key in zip(weights, small1))

# %%
fixed = Z_fixed = np.flipud(therm0.T)
plt.imshow(fixed, extent=extent, cmap='magma', vmin=0, vmax=1, aspect='auto')
plt.xlabel('Flux (Φ/Φ₀)')
plt.ylabel(r'$⟨n_r⟩$')
plt.ylim(0, 70)
plt.colorbar()
#ax.set_aspect("auto")
plt.title(r'$\Psi_{init} = |0⟩$')
fig.suptitle(title, fontsize=16)
plt.tight_layout()

# %%
fixed = Z_fixed = np.flipud(therm1.T)
plt.imshow(fixed, extent=extent, cmap='magma', vmin=1, vmax=2, aspect='auto')
plt.xlabel('Flux (Φ/Φ₀)')
plt.ylabel(r'$⟨n_r⟩$')
plt.ylim(0, 70)
plt.colorbar()
#ax.set_aspect("auto")
plt.title(r'$\Psi_{init} = |1⟩$')
fig.suptitle(title, fontsize=16)
plt.tight_layout()
