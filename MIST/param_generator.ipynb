# %%
import itertools
import numpy as np

# %%
# Define parameter values
step =.001
flux_array = np.arange(-.2, .6, step)
num_points = len(flux_array)
f_dim      = 30*np.ones(num_points)
r_dim      = 120*np.ones(num_points)

# %%
# Write to text file
with open("param_values.txt", "w") as f:
    for i in range(num_points):
        line = f"{flux_array[i]}"
        f.write(line + "\n")
